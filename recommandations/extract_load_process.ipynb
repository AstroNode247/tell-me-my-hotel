# %%
import pandas as pd
import json
import numpy as np
from tqdm import tqdm

import data_process as d

from DataProcessing import RecsData as recs

# %% [markdown]
# # Traitements des données
# Les données sont des fichiers textes sous la forme **JSON**. Il existe deux fichiers distinct : **offering** et **reviews**.
#
# ## Présentation de Offering
# Offering contient tous les hôtels valables à notre disposition.

# %%
df_offering = pd.read_csv('../data/optimiser/offering.csv')
df_offering.drop('Unnamed: 0', axis=1, inplace=True)
df_offering.head()
# Out:
#    hotel_class region_id                                                url  \
# 0          4.0     60763  http://www.tripadvisor.com/Hotel_Review-g60763...
# 1          5.0     32655  http://www.tripadvisor.com/Hotel_Review-g32655...
# 2          3.5     60763  http://www.tripadvisor.com/Hotel_Review-g60763...
# 3          4.0     60763  http://www.tripadvisor.com/Hotel_Review-g60763...
# 4          4.0     60763  http://www.tripadvisor.com/Hotel_Review-g60763...
#
#    phone details   type      id  \
# 0    NaN     NaN  hotel  113317
# 1    NaN     NaN  hotel   76049
# 2    NaN     NaN  hotel   99352
# 3    NaN     NaN  hotel   93589
# 4    NaN     NaN  hotel  217616
#
#                                               name address.region  \
# 0                    Casablanca Hotel Times Square             NY
# 1  Four Seasons Hotel Los Angeles at Beverly Hills             CA
# 2                   Hilton Garden Inn Times Square             NY
# 3                           The Michelangelo Hotel             NY
# 4                          The Muse Hotel New York             NY
#
#   address.street-address address.postal-code address.locality
# 0   147 West 43rd Street               10036    New York City
# 1        300 S Doheny Dr               90048      Los Angeles
# 2      790 Eighth Avenue               10019    New York City
# 3   152 West 51st Street               10019    New York City
# 4   130 West 46th Street               10036    New York City

# %% [markdown]
# ## Présentation de reviews
# Reviews contient les appréciations des clients dans différents hôtels.

# %%
reviews = pd.read_csv('../data/optimiser/full_reviews.csv')
reviews.drop('Unnamed: 0', axis=1, inplace=True)
reviews.head()
# Out:
#                                              title  \
# 0        “Truly is "Jewel of the Upper Wets Side"”
# 1                        “My home away from home!”
# 2                                     “Great Stay”
# 3                             “Modern Convenience”
# 4  “Its the best of the Andaz Brand in the US....”
#
#                                                 text  offering_id  \
# 0  Stayed in a king suite for 11 nights and yes i...        93338
# 1  On every visit to NYC, the Hotel Beacon is the...        93338
# 2  This is a great property in Midtown. We two di...      1762573
# 3  The Andaz is a nice hotel in a central locatio...      1762573
# 4  I have stayed at each of the US Andaz properti...      1762573
#
#    num_helpful_votes               date         id  via_mobile  \
# 0                  0  December 17, 2012  147643103       False
# 1                  0  December 17, 2012  147639004       False
# 2                  0  December 18, 2012  147697954       False
# 3                  0  December 17, 2012  147625723       False
# 4                  0  December 17, 2012  147612823       False
#
#    ratings.overall author.username                         author.id  ...  \
# 0              5.0      Papa_Panda  8C0B42FF3C0FA366A21CFD785302A032  ...
# 1              5.0       Maureen V  E3C85CA9DBBBC77E0DB534ABE93E4713  ...
# 2              4.0          vuguru  FB1032DECE1162CB3556D05F278AAFFD  ...
# 3              4.0  Hotel-Designer  EC3E275EE7590694889C8C7EE0D13961  ...
# 4              4.0       JamesE339  BA524A238B1171206691A6CC3F28F266  ...
#
#   ratings.value ratings.location  ratings.sleep_quality  ratings.rooms  \
# 0           5.0              5.0                    5.0            5.0
# 1           5.0              5.0                    5.0            5.0
# 2           4.0              5.0                    4.0            4.0
# 3           5.0              5.0                    5.0            5.0
# 4           3.0              5.0                    5.0            5.0
#
#    author.num_cities  author.num_helpful_votes  author.num_reviews  \
# 0               22.0                      12.0                29.0
# 1                2.0                       NaN                 2.0
# 2               12.0                      17.0                14.0
# 3                5.0                      26.0                 5.0
# 4               34.0                      65.0               104.0
#
#    author.num_type_reviews  ratings.check_in_front_desk  \
# 0                     24.0                          NaN
# 1                      NaN                          NaN
# 2                     14.0                          NaN
# 3                      5.0                          NaN
# 4                     49.0                          NaN
#
#    ratings.business_service_(e_g_internet_access)
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
# [5 rows x 24 columns]
